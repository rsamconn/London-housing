# %% [markdown]
# # Predicting house prices
#
# This notebook tests how simple Linear Regression models from scikit-learn do at predicting house price data.
#
# The goal is to apply some basic machine learning concepts - cross validation, hyperparameter tuning, component analysis - using lightweight models.
#
# We'll be using the following dataset from Kaggle: [Kaggle](https://www.kaggle.com/datasets/oktayrdeki/houses-in-london)
# - "10m_london_houses.csv" | 130 kB
#
# ## Contents
# 1. Data preprocessing
# 2. Training and tuning
# 3. Model Evaluation
# 4. Feature analysis
# 5. Summary
#
# Repository link: [Github](https://github.com/rsamconn/London-housing)

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Import models
from sklearn.linear_model import LinearRegression, Lasso, Ridge

print(np.NaN)
# Out:
# nan

# %%
# Load the data
housing_df = pd.read_csv('data/10m_london_houses_.csv')

print(f"Dataset shape: {housing_df.shape}")
display(housing_df.head())
# Out:
# Dataset shape: (1000, 17)
#                 Address  Neighborhood  Bedrooms  Bathrooms  Square Meters  \
# 0      78 Regent Street  Notting Hill         2          3            179
# 1     198 Oxford Street   Westminster         2          1            123
# 2      18 Regent Street          Soho         5          3            168
# 3  39 Piccadilly Circus     Islington         5          1            237
# 4      116 Fleet Street    Marylebone         4          1            127
#
#    Building Age Garden Garage  Floors  Property Type        Heating Type  \
# 0            72     No     No       3  Semi-Detached    Electric Heating
# 1            34    Yes     No       1      Apartment     Central Heating
# 2            38     No    Yes       3  Semi-Detached     Central Heating
# 3            53    Yes    Yes       1      Apartment  Underfloor Heating
# 4            23     No    Yes       2  Semi-Detached     Central Heating
#
#               Balcony Interior Style    View          Materials  \
# 0  High-level Balcony     Industrial  Garden             Marble
# 1  High-level Balcony     Industrial    City  Laminate Flooring
# 2          No Balcony     Industrial  Street               Wood
# 3          No Balcony        Classic    Park            Granite
# 4          No Balcony         Modern    Park               Wood
#
#   Building Status  Price (£)
# 0       Renovated    2291200
# 1             Old    1476000
# 2       Renovated    1881600
# 3       Renovated    1896000
# 4             Old    1524000

# %% [markdown]
# Our data has 1000 rows and 17 columns (6 columns of numeric data and 11 of categoric data).
#
# You can find a thorough analysis of them in the EDA notebook.
#
# ***
# ## 1 - Data preprocessing
# ***
#
# Before any analysis, we need to prepare our data.
#
# ### 1.1 Encoding
#
# First, encode the categorical data using dummy variables, since ```sklearn``` is designed only for numeric data.
#
# We drop the 'Address' column, because most of its values are unique so it would blow up our feature set without adding much prediction power.

# %%
# Check how many unique values are in the addresses column
print(f'Unique addresses: {housing_df["Address"].nunique()}')

# Drop the Address column, apply get_dummies to the remaining columns
housing_df_encoded = pd.get_dummies(housing_df.drop(columns=['Address']),
                                       drop_first=True).astype(np.float32)

cols_encoded = housing_df_encoded.columns
print(f'Columns after encoding ({len(cols_encoded)}):\n{cols_encoded}')
print(f'Data shape: {housing_df_encoded.shape}')
# Out:
# Unique addresses: 770
# Columns after encoding (36):
# Index(['Bedrooms', 'Bathrooms', 'Square Meters', 'Building Age', 'Floors',
#        'Price (£)', 'Neighborhood_Chelsea', 'Neighborhood_Greenwich',
#        'Neighborhood_Islington', 'Neighborhood_Kensington',
#        'Neighborhood_Marylebone', 'Neighborhood_Notting Hill',
#        'Neighborhood_Shoreditch', 'Neighborhood_Soho',
#        'Neighborhood_Westminster', 'Garden_Yes', 'Garage_Yes',
#        'Property Type_Detached House', 'Property Type_Semi-Detached',
#        'Heating Type_Electric Heating', 'Heating Type_Gas Heating',
#        'Heating Type_Underfloor Heating', 'Balcony_Low-level Balcony',
#        'Balcony_No Balcony', 'Interior Style_Industrial',
#        'Interior Style_Minimalist', 'Interior Style_Modern', 'View_Garden',
#        'View_Park', 'View_Sea', 'View_Street', 'Materials_Laminate Flooring',
#        'Materials_Marble', 'Materials_Wood', 'Building Status_Old',
#        'Building Status_Renovated'],
#       dtype='object')
# Data shape: (1000, 36)

# %% [markdown]
# ### 1.2 Split into training and evaluation data
# Second, let's set aside 100 randomly selected rows to be used for evaluating the model outputs later.

# %%
evaluation_set = housing_df_encoded.sample(frac=0.1, random_state=24)
training_df = housing_df_encoded.drop(evaluation_set.index).reset_index(drop=True)
evaluation_df = evaluation_set.reset_index(drop=True)

# %% [markdown]
# ### 1.3 Create target and feature sets
# Third, we separate out our features and target variable, and perform a train-test split on ```train_test_df```.
#
# Since we'll perform cross-validation with this set, it's necessary to hold out a separate set just for evaluation later.

# %%
# Separate evluation_df into features and target variable
X_eval = evaluation_df.drop(columns=['Price (£)']).values
y_eval = evaluation_df['Price (£)'].values
# Separate training_df into features and target variable
X = training_df.drop(columns=['Price (£)']).values
y = training_df['Price (£)'].values

# Perform train-test split on X
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=23)

print('Training data shape: ', X_train.shape, y_train.shape)
print('Test data shape: ', X_test.shape, y_test.shape)
print('Evaluation data shape: ', X_eval.shape, y_eval.shape)
# Out:
# Training data shape:  (630, 35) (630,)
# Test data shape:  (270, 35) (270,)
# Evaluation data shape:  (100, 35) (100,)

# %% [markdown]
# ### 1.4 Scaling
# Fourth and finally, scale the feature data using ```StandardScaler()```.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_eval_scaled = scaler.transform(X_eval)

# %% [markdown]
# Now we're ready to model!
#
# ***
# ## 2 - Modelling
# ***
#
# ### 2.1 - Only use house size
# It's often mentioned that the most important factor in determining house prices is the size.
#
# Let's take a look at that idea by building a model using only 'Square Meters' as a feature (SQM-only).

# %%
# Get Square Meters dolumns
sqm_column_ind = cols_encoded.get_loc('Square Meters')
X_train_sqm = X_train[:, sqm_column_ind].reshape(-1, 1)
X_test_sqm = X_test[:, sqm_column_ind].reshape(-1, 1)

# Use a Linear Regression model
linreg_sqm = LinearRegression()
linreg_sqm.fit(X_train_sqm, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# We want to generate price predictions from our model and plot them against the real prices, and also check the model's $R^2$ score.
#
# Let's create a function for this since we will want to repeat it later.

# %%
def score_predict_plot(model_dict,
                       X_train, y_train, X_test, y_test,
                       X_test1D, title='Model predictions'):
    """Plot predictions vs real values for multiple models and calculate their R2 scores."""
    
    # Create figure and plot the actual results
    plt.figure(figsize=(8, 6))
    plt.scatter(X_test1D, y_test, label='Real values', marker='D',
                color='black', alpha=0.9, s=20)
    
    # Loop over models
    for model_name, model in model_dict.items():
        # Calculate and print R² scores
        train_score = model.score(X_train, y_train)
        test_score = model.score(X_test, y_test)
        print(f"{model_name} training--testing R²: {train_score:.2f}--{test_score:.2f}")
        # Predict and plot
        y_pred = model.predict(X_test)
        plt.scatter(X_test1D, y_pred, label=f'{model_name}: R^2={test_score:.2f}', alpha=0.5, s=20)
        
    plt.xlabel('Square meters [m^2]', fontsize=11)
    plt.ylabel('Price [£]', fontsize=11)
    plt.title(title, fontsize=12, fontweight='bold')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %%
score_predict_plot({'Linear Regression (SQM-only)': linreg_sqm},
                   X_train_sqm, y_train, X_test_sqm, y_test,
                   X_test_sqm, title='Model predictions (SQM only)')
# Out:
# Linear Regression (SQM-only) training--testing R²: 0.64--0.61

# %% [markdown]
# The model has drawn a straight line through the data, as linear regression models are designed to do.
#
# The $R^2$ score of around 0.6 means it explains 60% of the variance in the data.
#
# Now let's train the models using _all_ the data.

# %% [markdown]
# ### 2.2 - look at all data
# First, we instantiate the models:

# %%
# Instantiate models for all features
models = {'Linear Regression': LinearRegression(),
              'Lasso': Lasso(alpha = 0.1),
              'Ridge': Ridge(alpha = 0.1)}

# %% [markdown]
# Let's see how these models perform out the box.

# %%
for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    # Print R² scores
    train_score = model.score(X_train_scaled, y_train)
    test_score = model.score(X_test_scaled, y_test)
    print(f"{name} training--testing R²: {train_score:.2f}--{test_score:.2f}")
# Out:
# Linear Regression training--testing R²: 0.95--0.95
# Lasso training--testing R²: 0.95--0.95
# Ridge training--testing R²: 0.95--0.95
# /Users/matt/opt/anaconda3/envs/root_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.600e+11, tolerance: 4.880e+10
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Wow - a 50% increase in the $R^2$ values compared to the SQM-only model!
#
# Unfortunately the `Lasso()` model also generates a convergence warning, which we will ignore for now.
#
# Let's see if we can improve that with some modest hyperparameter tuning.
#
# ### 2.3 Hyperparameter tuning
#
# We'll focus solely the `alpha` hyperparameter for the Lasso and Ridge models.
#
# We'll use random search cross validation to test 10 different values of `alpha` over 10 different folds of the training set.

# %%
from sklearn.model_selection import KFold, RandomizedSearchCV

# Set the hyperparameter grids for Lasso and Ridge
params = {'alpha': np.linspace(0.001, 10, 100)}
kf10 = KFold(n_splits=10, shuffle=True, random_state=24)

randomCV_lasso = RandomizedSearchCV(models['Lasso'], params, cv=kf10, n_iter=10, random_state=24)
randomCV_ridge = RandomizedSearchCV(models['Ridge'], params, cv=kf10, n_iter=10, random_state=24)

models_cvs = {'Lasso': randomCV_lasso,
              'Ridge': randomCV_ridge}

# Print the best scores and parameters
for name, model in models_cvs.items():
    model.fit(X_train_scaled, y_train)
    print('{} {} {}'.format(5*'-', name, 5*'-'))
    print(f'Top R^2 score: {model.best_score_:.4f}')
    print(f'Top params: {model.best_params_}')
# Out:
# ----- Lasso -----
# Top R^2 score: 0.9390
# Top params: {'alpha': 8.889}
# ----- Ridge -----
# Top R^2 score: 0.9391
# Top params: {'alpha': 3.738}

# %% [markdown]
# There's no gain of performance to be had here, however it's always good to check if the `alpha` values and train-test split we used earlier were representative of all the possible values or not (which, it turns out, they are).
#
# We see the best performing models had `alpha` values of around:
# - **8.9** for Lasso
# - **3.7** for Ridge.
#
# Let's save those best models and see how the predictions look now using the plotting fucnction defined earlier.

# %%
best_models = {'Linear Regression': models['Linear Regression'],
               'Lasso': randomCV_lasso.best_estimator_,
               'Ridge': randomCV_ridge.best_estimator_}

best_models['Linear Regression'].fit(X_train_scaled, y_train)

score_predict_plot(best_models,
                   X_train_scaled, y_train, X_test_scaled, y_test,
                   X_test_sqm, title='Predictions using all data')
# Out:
# Linear Regression training--testing R²: 0.95--0.95
# Lasso training--testing R²: 0.95--0.95
# Ridge training--testing R²: 0.95--0.95

# %% [markdown]
# The predictions look much better, especially in the middle (the lower the predictions are a bit too spread out and at the higher end they are too clustered, compared to the actual values).
#
# The test and training $R^2$ values are close, which is good because it implies we've avoided overfitting.
#
# Interestingly, the models all predict exactly the same points. Each model handles outliers differently so it could be that there are few outliers in this dataset, hence no differentiation between models.

# %% [markdown]
# ***
# ## 3 Model Evaluation
# ***
# Now that we are satisfied with our models, we can finally use our evaluation set to see how well they perform on unseen data.
#
# ### 3.1 Predictions on the evaluation set
# First, let's plot how the model predictions of the evaluation data perform.

# %%
score_predict_plot(best_models,
                   X_train_scaled, y_train, X_eval_scaled, y_eval,
                   X_eval_scaled[:, sqm_column_ind], title='Predictions using all data')
# Out:
# Linear Regression training--testing R²: 0.95--0.94
# Lasso training--testing R²: 0.95--0.94
# Ridge training--testing R²: 0.95--0.94

# %% [markdown]
# $R^2$ remains high, which means the models do well at explaining the variation even in unseen data.
#
# But how good are they at actually predicting house prices?
#
# ### 3.2 Performance metrics
#
# To understand this, we'll evaluate the models on 3 key parameters:
# - The Root Mean Squared Error (RMSE)
# - The Mean Aboslute Error (MAE) - this tells us on average how close our models' estimates are in £.
# - The Mean Aboslute Percentage Error (MAPE) - this tells us on average how close our models' estimates are in percentage terms.
#
# These will allow us to answer the question _'If I predict the price of a house, how close is it likely to be to the true value?'_

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def eval_models(model_dict, prediction_dict, y):
    '''Loop over a model dictionary and calculate the R2, RMSE, MAE and MAPE'''
    model_scores = {}
    for model_name in model_dict.keys():
        # print(f'----- {model_name} -----')
        # Calculate metrics
        model_r2 = np.round(r2_score(y, prediction_dict[model_name]), 2)
        model_rmse = np.round(np.sqrt(mean_squared_error(y, prediction_dict[model_name])), 2)
        model_mae = np.round(mean_absolute_error(y, prediction_dict[model_name]), 2)
        model_mape = np.round(np.mean(np.abs((y - prediction_dict[model_name]) / y)) * 100, 2)
        # Save to dataframe
        model_scores[model_name] = [model_r2, model_rmse, model_mae, model_mape]
        model_scores_df = pd.DataFrame(model_scores)
        model_scores_df.index = ['R^2', 'RMSE [£]', 'MAE [£]', 'MAPE [%]']
    return model_scores_df.transpose()

# %% [markdown]
# Evaluate our best models.

# %%
# Save prediction sets to a dictionary
eval_set_preds = {'Linear Regression': best_models['Linear Regression'].predict(X_eval_scaled),
                  'Lasso': best_models['Lasso'].predict(X_eval_scaled),
                  'Ridge': best_models['Ridge'].predict(X_eval_scaled)}

best_model_scores = eval_models(best_models, eval_set_preds, y_eval)
best_model_scores
# Out:
#                     R^2   RMSE [£]    MAE [£]  MAPE [%]
# Linear Regression  0.94  206933.88  157327.52     11.74
# Lasso              0.94  206916.50  157317.25     11.74
# Ridge              0.94  207397.17  157655.86     11.63

# %% [markdown]
# What do these results mean?
#
# Firstly, there remains little differentiation between models.
#
# Secondly, the models still can't predict house prices that accurately, despite their high $R^2$ scores.
# The best MAPE score of 11.64% is a sizeable margin of error - it translates to being _over £150,000 off_ the real price on averge - ouch!
#
# Still the point is that these are simple models - they're really the minimum of what ML has to offer, and they can still get within 12% of the real price.
#
# With more complex models, more hyperparameter tuning and a larger dataset you could make much more accurate models.

# %% [markdown]
# ***
# ## 4 - Feature Analysis
# ***
#
# What can the models tell us about the most important factors in determining the house price?
#
# We can evaluate the feature coefficients to find out.
#
# ### 4.1 - Feature coefficients

# %%
# Extract and sort the coefficient data
lasso_coeff = best_models['Lasso'].coef_
lasso_coef_df = pd.DataFrame([evaluation_df.drop(columns=['Price (£)']).columns, lasso_coeff]).transpose()
lasso_coef_df.columns=['Features', 'Coefficients']
lasso_coef_df['Abs. Coeff.'] = np.abs(lasso_coef_df['Coefficients'])

# Plot the coefficients, sorted by absolute value
plt.figure(figsize=(10, 8))
plt.barh(lasso_coef_df.sort_values('Abs. Coeff.')['Features'],
         lasso_coef_df.sort_values('Abs. Coeff.')['Coefficients'])
plt.xlabel('Coefficient Value')
plt.title('Lasso Coefficients for all features')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# What does this tell us?
#
# Firstly, the size in square meters of a house has the biggest coefficient, as we might expect.
#
# 9 of the top 12 features are the neighbourhood a house is in. Note that the model thinks that areas like Islington are actually _bad_ for house prices, despite absolutely being sought after in real life - we can put this down to the training set including only high value areas, so naturally the least high value areas don't appear as good.
#
# In the bottom end it seems that things like having a garden, a garage or a nice view do not affect price much.
#
# Interestingly, the number of bedrooms and bathrooms also has little effect, perhaps because these features are effectively included in the Square Meters value.
#
# ### 4.2 Dimensionality Reduction
#
# Let's see how well a model can do using just the top 12 features.

# %%
# Get top features
top_features = lasso_coef_df.sort_values('Abs. Coeff.', ascending=False)\
                .reset_index().loc[:11, :]['Features']
# Get the indices of the top features
top_feature_indices = lasso_coef_df[lasso_coef_df['Features'].isin(top_features)].index.tolist()
# Get the columns of the scaled feature sets for the top features
X_train_top = X_train_scaled[:, top_feature_indices]
X_test_top = X_test_scaled[:, top_feature_indices]
X_eval_top = X_eval_scaled[:, top_feature_indices]

# %% [markdown]
# Now let's make a model using only the top feature data.

# %%
# Create and tune the model
randomCV_lasso_top = RandomizedSearchCV(Lasso(), params, cv=kf10,
                                        n_iter=20, random_state=24)
randomCV_lasso_top.fit(X_train_top, y_train)

# Evaluate the model
print(f'Top score: {randomCV_lasso_top.best_score_:.4f}')
print(f'Top params: {randomCV_lasso_top.best_params_}')

lasso_top_preds = randomCV_lasso_top.best_estimator_.predict(X_eval_top)
eval_models({'Lasso (top features)': randomCV_lasso_top.best_estimator_},
            {'Lasso (top features)': lasso_top_preds},
            y_eval)
# Out:
# Top score: 0.9409
# Top params: {'alpha': 9.495}
#                        R^2   RMSE [£]    MAE [£]  MAPE [%]
# Lasso (top features)  0.94  195373.73  147393.95     10.79

# %% [markdown]
# Despite using 66% less data, the new model has in fact turned out marginally better than the previous models.

# %% [markdown]
# ***
# Summary
# ***
#
# What have we learned?
#
# - The claim that house size is the primary determinant of price seems to hold up given the quick analysis in Section 2.1 and the feature analysis in Section 4.1.
# - From Section 4.1, the other primary determinants of price seem to be
#     - The neighborhood (i.e. the location).
#     - The house type (Detached > semi-detached > apartment)
# - Almost everything else seems to have very little effect on price, according to these models.
# - From Section 3.2, the models unfortunately don't perform that well:
#     - Their predictions are all out by well over £100k on average - if you found out you were going to have to pay £100k more on a house than expected, you would not be happy.
#     - The model results are very close, possibly because they data doesn't contain many outliers.
#     - _However_, we should keep in mind these are simple, lightweight models - there are many things that could be changed to improve the prediction accuracy.
# - From Section 4.2, we could build models that performed just as well using only a third of the features.
#
# In conclusion, with a little bit of modelling and a little bit of analysis we created some simple models to predict house prices. They didn't perform that well, but they could be used as a baseline to test new models against.
#
# There's a lot of performance to be gained from doing more tuning, using a larger dataset, and using different, perhaps non-linear models.

# %% [markdown]
# ***
# #### BONUS: Residual analysis
# ***
#
# Getting a better understanding of how model predictions compare to the true values.

# %%
import scipy.stats as stats
residuals = {
    'LinReg': y_eval - eval_set_preds['Linear Regression'],
    'Lasso': y_eval - eval_set_preds['Lasso'],
    'Ridge': y_eval - eval_set_preds['Ridge']
}

# %%
def plot_residuals(residuals_dict, predictions_dict, y_true, save_plots=False, verbose=True):
    """Plot residuals for multiple models."""
    fig = plt.figure(figsize=(16, 12))

    # 1. Residuals vs Predicted (Test Set)
    ax1 = plt.subplot(2, 3, 1)
    for model_name, residuals in residuals_dict.items():
        ax1.scatter(predictions_dict[model_name], residuals, alpha=0.5, s=20, label=model_name)
    ax1.axhline(y=0, color='r', linestyle='--', linewidth=2)
    ax1.set_xlabel('Predicted Price (£)')
    ax1.set_ylabel('Residuals (£)')
    ax1.set_title('Residuals vs Predicted (Test Set)')
    ax1.grid(True, alpha=0.3)

    # 2. Residuals vs Actual (Test Set)
    ax2 = plt.subplot(2, 3, 2)
    for model_name, residuals in residuals_dict.items():
        ax2.scatter(y_true, residuals, alpha=0.5, s=20, label=model_name)
    ax2.axhline(y=0, color='r', linestyle='--', linewidth=2)
    ax2.set_xlabel('Actual Price (£)')
    ax2.set_ylabel('Residuals (£)')
    ax2.set_title('Residuals vs Actual (Test Set)')
    ax2.grid(True, alpha=0.3)

    # 3. Histogram of Residuals
    ax3 = plt.subplot(2, 3, 3)
    for model_name, residuals in residuals_dict.items():
        # ax3.hist(residuals, bins=50, edgecolor='black', alpha=0.7, label=model_name)
        sns.histplot(residuals, kde=True, label=model_name, alpha=0.5)
    ax3.axvline(x=0, color='r', linestyle='--', linewidth=2)
    ax3.set_xlabel('Residuals (£)')
    ax3.set_ylabel('Frequency')
    ax3.set_title('Distribution of Residuals (Test Set)')
    ax3.grid(True, alpha=0.3)

    # 4. Q-Q Plot
    ax4 = plt.subplot(2, 3, 4)
    for model_name, residuals in residuals_dict.items():
        stats.probplot(residuals, dist="norm", plot=plt)
    ax4.set_title('Q-Q Plot (Normality Check)')
    ax4.grid(True, alpha=0.3)

    # 5. Scale-Location Plot (Sqrt of standardized residuals)
    ax5 = plt.subplot(2, 3, 5)
    for model_name, residuals in residuals_dict.items():
        standardized_residuals = residuals / np.std(residuals)
        ax5.scatter(y_true, np.sqrt(np.abs(standardized_residuals)), alpha=0.5, s=20, label=model_name)
    ax5.set_xlabel('Predicted Price (£)')
    ax5.set_ylabel('√|Standardized Residuals|')
    ax5.set_title('Scale-Location Plot (Homoscedasticity Check)')
    ax5.grid(True, alpha=0.3)

    # 6. Predicted vs Actual
    ax6 = plt.subplot(2, 3, 6)
    for model_name, residuals in residuals_dict.items():
        ax6.scatter(y_true, predictions_dict[model_name], alpha=0.5, s=20, label=model_name)
    min_val = min(y_true.min(), y_true.min())
    max_val = max(y_true.max(), y_true.max())
    ax6.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='Perfect Prediction')
    ax6.set_xlabel('Actual Price (£)')
    ax6.set_ylabel('Predicted Price (£)')
    ax6.set_title('Predicted vs Actual (Test Set)')
    ax6.legend()
    ax6.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
plot_residuals({'Lasso (top features)': y_eval - lasso_top_preds},
                {'Lasso (top features)': lasso_top_preds},
                y_eval)
